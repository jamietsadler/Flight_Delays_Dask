# %% [markdown]
# # Flight & Weather Data With Dask

# %%
from dask import delayed
import dask.dataframe as dd

import pandas as pd

# %% [markdown]
# ### Explore one flight and one weather dataset

# %%
df = pd.read_csv('datasets/flightdelays/flightdelays-2016-1.csv')

# %%
df.head()
# Out:
#       FL_DATE UNIQUE_CARRIER  FL_NUM ORIGIN     ORIGIN_CITY_NAME  \
# 0  2016-01-01             F9     214    DEN           Denver, CO
# 1  2016-01-01             DL    2035    MKE        Milwaukee, WI
# 2  2016-01-01             AA    1715    PIT       Pittsburgh, PA
# 3  2016-01-01             B6    1126    FLL  Fort Lauderdale, FL
# 4  2016-01-01             OO    5546    SAT      San Antonio, TX
#
#   ORIGIN_STATE_ABR ORIGIN_STATE_NM DEST      DEST_CITY_NAME DEST_STATE_ABR  \
# 0               CO        Colorado  AUS          Austin, TX             TX
# 1               WI       Wisconsin  ATL         Atlanta, GA             GA
# 2               PA    Pennsylvania  DCA      Washington, DC             VA
# 3               FL         Florida  RDU  Raleigh/Durham, NC             NC
# 4               TX           Texas  SFO   San Francisco, CA             CA
#
#    ... CRS_ARR_TIME  ARR_DELAY  CANCELLED  DIVERTED  CARRIER_DELAY  \
# 0  ...         1145      -14.0        0.0       0.0            NaN
# 1  ...         1830      -16.0        0.0       0.0            NaN
# 2  ...         2009      -12.0        0.0       0.0            NaN
# 3  ...         1957        2.0        0.0       0.0            NaN
# 4  ...          939       11.0        0.0       0.0            NaN
#
#    WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 22
# 0            NaN        NaN             NaN                  NaN          NaN
# 1            NaN        NaN             NaN                  NaN          NaN
# 2            NaN        NaN             NaN                  NaN          NaN
# 3            NaN        NaN             NaN                  NaN          NaN
# 4            NaN        NaN             NaN                  NaN          NaN
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#              FL_NUM  CRS_DEP_TIME     DEP_DELAY  CRS_ARR_TIME     ARR_DELAY  \
# count  89165.000000  89165.000000  89165.000000  89165.000000  86628.000000
# mean    2078.778691   1331.873314     10.529030   1504.529973      1.551057
# std     1759.972293    483.144848     35.793569    506.048734     39.418018
# min        1.000000      1.000000      0.000000      1.000000    -74.000000
# 25%      696.000000    920.000000      0.000000   1119.000000    -15.000000
# 50%     1597.000000   1328.000000      0.000000   1530.000000     -7.000000
# 75%     2763.000000   1730.000000      5.000000   1923.000000      5.000000
# max     7438.000000   2359.000000   1597.000000   2359.000000   1568.000000
#
#           CANCELLED      DIVERTED  CARRIER_DELAY  WEATHER_DELAY     NAS_DELAY  \
# count  89165.000000  89165.000000   14255.000000   14255.000000  14255.000000
# mean       0.026400      0.002052      20.624483       2.664048     12.910908
# std        0.160324      0.045257      57.563433      21.838650     26.019974
# min        0.000000      0.000000       0.000000       0.000000      0.000000
# 25%        0.000000      0.000000       0.000000       0.000000      0.000000
# 50%        0.000000      0.000000       3.000000       0.000000      2.000000
# 75%        0.000000      0.000000      20.000000       0.000000     18.000000
# max        1.000000      1.000000    1568.000000     669.000000    668.000000
#
#        SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 22
# count    14255.000000         14255.000000          0.0
# mean         0.076043            21.671624          NaN
# std          2.452460            42.816538          NaN
# min          0.000000             0.000000          NaN
# 25%          0.000000             0.000000          NaN
# 50%          0.000000             0.000000          NaN
# 75%          0.000000            26.000000          NaN
# max        233.000000          1026.000000          NaN

# %% [markdown]
# Can see there is a lot of data, as this is one of 10 csv files for the project

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89165 entries, 0 to 89164
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FL_DATE              89165 non-null  object
#  1   UNIQUE_CARRIER       89165 non-null  object
#  2   FL_NUM               89165 non-null  int64
#  3   ORIGIN               89165 non-null  object
#  4   ORIGIN_CITY_NAME     89165 non-null  object
#  5   ORIGIN_STATE_ABR     89165 non-null  object
#  6   ORIGIN_STATE_NM      89165 non-null  object
#  7   DEST                 89165 non-null  object
#  8   DEST_CITY_NAME       89165 non-null  object
#  9   DEST_STATE_ABR       89165 non-null  object
#  10  DEST_STATE_NM        89165 non-null  object
#  11  CRS_DEP_TIME         89165 non-null  int64
#  12  DEP_DELAY            89165 non-null  float64
#  13  CRS_ARR_TIME         89165 non-null  int64
#  14  ARR_DELAY            86628 non-null  float64
#  15  CANCELLED            89165 non-null  float64
#  16  DIVERTED             89165 non-null  float64
#  17  CARRIER_DELAY        14255 non-null  float64
#  18  WEATHER_DELAY        14255 non-null  float64
#  19  NAS_DELAY            14255 non-null  float64
#  20  SECURITY_DELAY       14255 non-null  float64
#  21  LATE_AIRCRAFT_DELAY  14255 non-null  float64
#  22  Unnamed: 22          0 non-null      float64
# dtypes: float64(10), int64(3), object(10)
# memory usage: 15.6+ MB

# %%
df.DEP_DELAY.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df.UNIQUE_CARRIER.nunique()
# Out:
# 12
